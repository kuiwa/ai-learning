# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
data = {
    'a': np.arange(50),
    'c': np.random.randint(0, 50, 50),
    'd': np.random.randn(50)
}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

# doesn't work, subplot doesn't have figsize parameter, need to use figure firstly, then subplot
# fig, ax = plt.subplot(figsize=(5, 2.7), layout='constrained')
# ax.scatter('a', 'b', c='c', s='d', data=data)
# ax.set_xlabel('entry a')
# ax.set_ylabel('entry b')

# way 1, recommended
plt.figure(figsize=(5, 2.7), layout='constrained')
ax = plt.subplot()
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# ax.set_xlim(10, 40) # set x axis range

# way 2
# plt.figure(figsize=(5, 2.7), layout='constrained')
# plt.subplot()
# plt.scatter('a', 'b', c='c', s='d', data=data)
# plt.xlabel('entry a')
# plt.ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')
